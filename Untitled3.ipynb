# %%
import pandas as pd
df = pd.read_csv('/Users/a2/.cache/immodynamics/1666562745/main.csv')
for i in range(len(df['enbed'])):
    df.loc['enbed', i] = int(df.loc['enbed', i].split(" ").replace(",","."))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [46], in <cell line: 3>()
#       2 df = pd.read_csv('/Users/a2/.cache/immodynamics/1666562745/main.csv')
#       3 for i in range(len(df['enbed'])):
# ----> 4     df.loc['enbed', i] = int(df.loc['enbed', i].split(" ").replace(",","."))
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:925, in _LocationIndexer.__getitem__(self, key)
#     923         with suppress(KeyError, IndexError):
#     924             return self.obj._get_value(*key, takeable=self._takeable)
# --> 925     return self._getitem_tuple(key)
#     926 else:
#     927     # we by definition only have the 0th axis
#     928     axis = self.axis or 0
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1100, in _LocIndexer._getitem_tuple(self, tup)
#    1098 def _getitem_tuple(self, tup: tuple):
# ...

# %%
import plotly.express as px
df = df[df['effclass'] < 3]
fig = px.scatter(df, x=df['preis']/df['qm'], y='plz', color='effclass', hover_name='id',opacity=0.7, color_continuous_scale='bluered')
fig.show()
import time
time_now = int(time.time())
import plotly
plotly.offline.plot(fig, filename=f'/Users/a2/.cache/immodynamics/{time_now}.html')
# Out:
# '/Users/a2/.cache/immodynamics/1667053824.html'

# %%
df.head(100)
# Out:
#     Unnamed: 0  Unnamed: 0.1          id  \
# 0            0             0  iwe27fnt5j
# 1            1             0  iwe267ty5z
# 2            2             0  iwe25dz45h
# 3            3             0  iwe26p7l5y
# 4            4             0  iwe27t2f54
# ..         ...           ...         ...
# 95          95             0  iwe27ymz5k
# 96          96             0  iwe26jsf59
# 97          97             0  iwe279q55l
# 98          98             0  iwe27bgy5b
# 99          99             0  iwe27csa52
#
#                                        url  preis  typ   qm  zimmer    plz  \
# 0   https://www.immowelt.de/expose/27fnt5j    790    1   49       1  93051
# 1   https://www.immowelt.de/expose/267ty5z    875    1   75       2  92224
# 2   https://www.immowelt.de/expose/25dz45h   1050    1   84       3  90491
# 3   https://www.immowelt.de/expose/26p7l5y    815    1   63       2  90443
# 4   https://www.immowelt.de/expose/27t2f54    654    1   78       3  84489
# ...

# %%
fig2 = px.scatter(df, x='effclass', y='enbed')

# %%
fig2.show()

# %%
verbrauch = 179 # in kWh
co2 = 798 # in g/kwh
g_pro_Jahr = verbrauch * co2

# %%
g_pro_Jahr/=1000
g_pro_Jahr/=1000

# %%
t_p_J = g_pro_Jahr
ppt = 55
ppt * t_p_J * 80
# Out:
# 628.5048000000002
